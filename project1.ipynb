# %% [markdown]
# # Project title:Student Result Analysis

# %% [markdown]
# ## Purpose

# %% [markdown]
# The aim of this project is to understand what factors impact how well students perform in school. By looking at things like gender, ethnicity, how educated their parents are, and other aspects like study habits and interests outside of school, we hope to figure out what helps students succeed and what might hold them back. With this knowledge, we can try to create better ways to support students and make sure everyone has the chance to do well in school.

# %% [markdown]
# ## Step 1 : Importing necessary packages

# %%
# Importing necessary packages for data manipulating and visualization
import numpy as np  # NumPy for numerical computations and efficient array operations
import pandas as pd # pandas for data manipulation
import matplotlib.pyplot as plt # Matplotlib for data visualization
import seaborn as sns # Seaborn for statistical data visualization
import os # OS module for interacting with the operating system

# %% [markdown]
# ## Step 2 : Loading the data from the local system to the jupyter notebook

# %%
# Load the files
df=pd.read_csv(r"Student_Score.csv")
# Print the dataset
print(df)
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 0               0  female         NaN   bachelor's degree      standard
# 1               1  female     group C        some college      standard
# 2               2  female     group B     master's degree      standard
# 3               3    male     group A  associate's degree  free/reduced
# 4               4    male     group C        some college      standard
# ...           ...     ...         ...                 ...           ...
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 0           none             married     regularly          yes         3.0
# 1            NaN             married     sometimes          yes         0.0
# 2           none              single     sometimes          yes         4.0
# 3           none             married         never           no         1.0
# 4           none             married     sometimes          yes         0.0
# ...          ...                 ...           ...          ...         ...
# 30636       none              single     sometimes           no         2.0
# 30637       none              single     regularly           no         1.0
# 30638  completed             married     sometimes           no         1.0
# 30639  completed             married     regularly           no         3.0
# 30640       none             married         never           no         1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0         school_bus            < 5         71            71            74
# 1                NaN         5 - 10         69            90            88
# 2         school_bus            < 5         87            93            91
# 3                NaN         5 - 10         45            56            42
# 4         school_bus         5 - 10         76            78            75
# ...              ...            ...        ...           ...           ...
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [30641 rows x 15 columns]

# %% [markdown]
# ## Step 3 : Data View

# %%
# Display the first 5 rows of the dataset
df.head()
# Out:
#    Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0           0  female         NaN   bachelor's degree      standard     none
# 1           1  female     group C        some college      standard      NaN
# 2           2  female     group B     master's degree      standard     none
# 3           3    male     group A  associate's degree  free/reduced     none
# 4           4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
#   WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0            < 5         71            71            74
# 1         5 - 10         69            90            88
# 2            < 5         87            93            91
# 3         5 - 10         45            56            42
# 4         5 - 10         76            78            75

# %%
# Display the last 5 rows of the dataset
df.tail()
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30638         911  female         NaN         high school  free/reduced
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 30636       none              single     sometimes           no         2.0
# 30637       none              single     regularly           no         1.0
# 30638  completed             married     sometimes           no         1.0
# 30639  completed             married     regularly           no         3.0
# 30640       none             married         never           no         1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30638        private         5 - 10         61            70            67
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58

# %%
# Prints the list of column names of the dataset
df.columns
# Out:
# Index(['Unnamed: 0', 'Gender', 'EthnicGroup', 'ParentEduc', 'LunchType',
#        'TestPrep', 'ParentMaritalStatus', 'PracticeSport', 'IsFirstChild',
#        'NrSiblings', 'TransportMeans', 'WklyStudyHours', 'MathScore',
#        'ReadingScore', 'WritingScore'],
#       dtype='object')

# %%
# Displays the summary of the dataset including non-null counts and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30641 entries, 0 to 30640
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           30641 non-null  int64
#  1   Gender               30641 non-null  object
#  2   EthnicGroup          28801 non-null  object
#  3   ParentEduc           28796 non-null  object
#  4   LunchType            30641 non-null  object
#  5   TestPrep             28811 non-null  object
#  6   ParentMaritalStatus  29451 non-null  object
#  7   PracticeSport        30010 non-null  object
#  8   IsFirstChild         29737 non-null  object
#  9   NrSiblings           29069 non-null  float64
#  10  TransportMeans       27507 non-null  object
#  11  WklyStudyHours       29686 non-null  object
#  12  MathScore            30641 non-null  int64
#  13  ReadingScore         30641 non-null  int64
#  14  WritingScore         30641 non-null  int64
# dtypes: float64(1), int64(4), object(10)
# memory usage: 3.5+ MB

# %%
# Displays the dimensions of the dataset as a tuple
df.shape
# Out:
# (30641, 15)

# %%
# Displays the data types of each column
df.dtypes
# Out:
# Unnamed: 0               int64
# Gender                  object
# EthnicGroup             object
# ParentEduc              object
# LunchType               object
# TestPrep                object
# ParentMaritalStatus     object
# PracticeSport           object
# IsFirstChild            object
# NrSiblings             float64
# TransportMeans          object
# WklyStudyHours          object
# MathScore                int64
# ReadingScore             int64
# WritingScore             int64
# dtype: object

# %%
# Generating descriptive statistics of the numerical columns in a dataset
df.describe()
# Out:
#          Unnamed: 0    NrSiblings     MathScore  ReadingScore  WritingScore
# count  30641.000000  29069.000000  30641.000000  30641.000000  30641.000000
# mean     499.556607      2.145894     66.558402     69.377533     68.418622
# std      288.747894      1.458242     15.361616     14.758952     15.443525
# min        0.000000      0.000000      0.000000     10.000000      4.000000
# 25%      249.000000      1.000000     56.000000     59.000000     58.000000
# 50%      500.000000      2.000000     67.000000     70.000000     69.000000
# 75%      750.000000      3.000000     78.000000     80.000000     79.000000
# max      999.000000      7.000000    100.000000    100.000000    100.000000

# %% [markdown]
# ## Step 4 : Data Cleaning (filteration / manipulation)

# %%
# Shows the count of non-null values in the particular column
df.count()
# Out:
# Unnamed: 0             30641
# Gender                 30641
# EthnicGroup            28801
# ParentEduc             28796
# LunchType              30641
# TestPrep               28811
# ParentMaritalStatus    29451
# PracticeSport          30010
# IsFirstChild           29737
# NrSiblings             29069
# TransportMeans         27507
# WklyStudyHours         29686
# MathScore              30641
# ReadingScore           30641
# WritingScore           30641
# dtype: int64

# %%
# Count the frequency of unique values in each column of the dataset
df.value_counts()
# Out:
# Unnamed: 0  Gender  EthnicGroup  ParentEduc          LunchType     TestPrep   ParentMaritalStatus  PracticeSport  IsFirstChild  NrSiblings  TransportMeans  WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0           female  group A      some college        standard      completed  married              regularly      yes           5.0         private         > 10            86         96            99              1
# 670         male    group B      master's degree     standard      none       single               sometimes      no            3.0         school_bus      5 - 10          88         83            80              1
#             female  group D      master's degree     standard      completed  single               never          yes           3.0         school_bus      > 10            93         99            99              1
#                     group C      some college        standard      completed  married              never          yes           0.0         school_bus      < 5             65         78            72              1
#                                  high school         free/reduced  none       married              never          no            2.0         school_bus      < 5             62         73            64              1
#                                                                                                                                                                                                                     ..
# 335         female  group B      high school         standard      completed  divorced             never          yes           0.0         private         5 - 10          76         87            86              1
#                                  associate's degree  standard      none       single               sometimes      no            3.0         private         < 5             53         57            63              1
#                                                      free/reduced  none       married              sometimes      no            2.0         school_bus      5 - 10          39         48            47              1
#                     group A      master's degree     free/reduced  none       married              regularly      yes           2.0         private         < 5             76         89            87              1
# 999         male    group E      some high school    free/reduced  none       divorced             sometimes      yes           1.0         school_bus      < 5             74         65            59              1
# Name: count, Length: 19243, dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                0
# Gender                    0
# EthnicGroup            1840
# ParentEduc             1845
# LunchType                 0
# TestPrep               1830
# ParentMaritalStatus    1190
# PracticeSport           631
# IsFirstChild            904
# NrSiblings             1572
# TransportMeans         3134
# WklyStudyHours          955
# MathScore                 0
# ReadingScore              0
# WritingScore              0
# dtype: int64

# %%
# Removing the Unnamed Column
df.drop("Unnamed: 0", axis=1,inplace=True)
print(df.head())
# Out:
#    Gender EthnicGroup          ParentEduc     LunchType TestPrep  \
# 0  female         NaN   bachelor's degree      standard     none
# 1  female     group C        some college      standard      NaN
# 2  female     group B     master's degree      standard     none
# 3    male     group A  associate's degree  free/reduced     none
# 4    male     group C        some college      standard     none
#
#   ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings TransportMeans  \
# 0             married     regularly          yes         3.0     school_bus
# 1             married     sometimes          yes         0.0            NaN
# 2              single     sometimes          yes         4.0     school_bus
# 3             married         never           no         1.0            NaN
# 4             married     sometimes          yes         0.0     school_bus
#
#   WklyStudyHours  MathScore  ReadingScore  WritingScore
# 0            < 5         71            71            74
# 1         5 - 10         69            90            88
# 2            < 5         87            93            91
# 3         5 - 10         45            56            42
# 4         5 - 10         76            78            75

# %%
# Drop rows with any missing values (NaN) from the dataset
df.dropna()
# Out:
#        Unnamed: 0  Gender EthnicGroup          ParentEduc     LunchType  \
# 2               2  female     group B     master's degree      standard
# 4               4    male     group C        some college      standard
# 5               5  female     group B  associate's degree      standard
# 6               6  female     group B        some college      standard
# 7               7    male     group B        some college  free/reduced
# ...           ...     ...         ...                 ...           ...
# 30635         794    male     group C        some college      standard
# 30636         816  female     group D         high school      standard
# 30637         890    male     group E         high school      standard
# 30639         934  female     group D  associate's degree      standard
# 30640         960    male     group B        some college      standard
#
#         TestPrep ParentMaritalStatus PracticeSport IsFirstChild  NrSiblings  \
# 2           none              single     sometimes          yes         4.0
# 4           none             married     sometimes          yes         0.0
# 5           none             married     regularly          yes         1.0
# 6      completed             widowed         never           no         1.0
# 7           none             married     sometimes          yes         1.0
# ...          ...                 ...           ...          ...         ...
# 30635       none             married     regularly           no         2.0
# 30636       none              single     sometimes           no         2.0
# 30637       none              single     regularly           no         1.0
# 30639  completed             married     regularly           no         3.0
# 30640       none             married         never           no         1.0
#
#       TransportMeans WklyStudyHours  MathScore  ReadingScore  WritingScore
# 2         school_bus            < 5         87            93            91
# 4         school_bus         5 - 10         76            78            75
# 5         school_bus         5 - 10         73            84            79
# 6            private         5 - 10         85            93            89
# 7            private           > 10         41            43            39
# ...              ...            ...        ...           ...           ...
# 30635     school_bus         5 - 10         58            53            49
# 30636     school_bus         5 - 10         59            61            65
# 30637        private         5 - 10         58            53            51
# 30639     school_bus         5 - 10         82            90            93
# 30640     school_bus         5 - 10         64            60            58
#
# [19243 rows x 15 columns]

# %%
# Drop rows with any missing values (NaN) from the dataset and update the dataset in place
df.dropna(inplace=True)

# %%
# Check the dimensions of the dataset after dropping rows with missing values
df.shape
# Out:
# (19243, 15)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0             0
# Gender                 0
# EthnicGroup            0
# ParentEduc             0
# LunchType              0
# TestPrep               0
# ParentMaritalStatus    0
# PracticeSport          0
# IsFirstChild           0
# NrSiblings             0
# TransportMeans         0
# WklyStudyHours         0
# MathScore              0
# ReadingScore           0
# WritingScore           0
# dtype: int64

# %%
# Identify and store duplicated rows in the dataset
duplicate_rows = df.duplicated()

# Print the number of duplicated rows found in the dataset
print(duplicate_rows.sum())
# Out:
# 0

# %% [markdown]
# ## Step 5 : Data Visualization

# %%
# Creating a bar chart for Gender Distribution
plt.figure(figsize=(5,5))
ax = sns.countplot(data=df,x='Gender')
ax.bar_label(ax.containers[0])
plt.title("Gender Distribution")
plt.show()

# %% [markdown]
# from the above chart we have analysed that the number of femailes in the data is more than the number of males

# %%
# Scores percentages between genders
df.groupby(['Gender']).agg({'MathScore':'mean', 'ReadingScore':'mean', 'WritingScore':'mean'})
# Out:
#         MathScore  ReadingScore  WritingScore
# Gender
# female  64.256164     73.068338     73.070588
# male    69.091994     65.885720     63.990283

# %%
By observing above we conclude that females were scored more than males

# %%
# Calculating the mean to find Relationship between Parent's Education and Student's Score
gb= df.groupby("ParentEduc").agg({"MathScore":"mean","ReadingScore":'mean','WritingScore':'mean'})
print(gb)
# Out:
#                     MathScore  ReadingScore  WritingScore
# ParentEduc
# associate's degree  68.541478     71.317685     70.551080
# bachelor's degree   70.724379     73.560401     73.873964
# high school         64.294461     67.284124     65.495892
# master's degree     72.293680     75.922677     76.423792
# some college        66.578305     69.300113     68.651525
# some high school    62.522417     65.438218     63.572171

# %%
# Creating heatmap of Relationship between Parent's Education and Student's Score
plt.figure(figsize=(4,4))
sns.heatmap(gb,annot=True)
plt.title("Relationship between Parent's Education and Student's Score")
plt.show()

# %% [markdown]
# from the above chart we have concluded that the education of the have a good impact on their scores

# %%
# Creating heatmap of Relationship between Parent's Martial status and Student's Score
gb1= df.groupby("ParentMaritalStatus").agg({"MathScore":"mean","ReadingScore":'mean','WritingScore':'mean'})
print(gb1)
# Out:
#                      MathScore  ReadingScore  WritingScore
# ParentMaritalStatus
# divorced             66.691197     69.655011     68.799146
# married              66.657326     69.389575     68.420981
# single               66.165704     69.157250     68.174440
# widowed              67.368866     69.651438     68.563452

# %%
plt.figure(figsize=(4,4))
sns.heatmap(gb1,annot=True)
plt.title("Relationship between Parent's Marital status and Student's Score")
plt.show()

# %% [markdown]
# from the above chart we have concluded that there is no/negligiable impact on the student score due to their marital status

# %%
# Creating box chart for Math score
sns.boxplot(data=df,x="MathScore")
plt.show()

# %%
# Creating box chart for Reading score
sns.boxplot(data=df,x="ReadingScore")
plt.show()

# %%
# Creating box chart for Writing score
sns.boxplot(data=df,x="WritingScore")
plt.show()

# %%
print(df["EthnicGroup"].unique())
# Out:
# [nan 'group C' 'group B' 'group A' 'group D' 'group E']

# %%
# Distribution of Ethnic Groups
groupA=df.loc[(df['EthnicGroup'] == 'group A')].count()
groupB=df.loc[(df['EthnicGroup'] == 'group B')].count()
groupC=df.loc[(df['EthnicGroup'] == 'group C')].count()
groupD=df.loc[(df['EthnicGroup'] == 'group D')].count()
groupE=df.loc[(df['EthnicGroup'] == 'group E')].count()
l=['group A','group B','group C','group D','group E']
mlist=[groupA['EthnicGroup'],groupB['EthnicGroup'],groupC['EthnicGroup'],groupD['EthnicGroup'],groupE['EthnicGroup']]
plt.pie(mlist,labels=l,autopct='%1.2f%%')
plt.title('Distribution of Ethnic Groups')
plt.show()

# %% [markdown]
# By comparing ethinic groups group E has highest percentage and group A has lowest percentage

# %%
# Creating  bar chart for Ethnic groups
ax=sns.countplot(data=df,x='EthnicGroup')
ax.bar_label(ax.containers[0]) 
plt.show()

# %% [markdown]
# From above bar chart we can observe that more student are from group E and less students from grop A

# %%
# Creating  bar chart for Ethnic groups
ax=sns.countplot(x=df['WklyStudyHours'],order=['5 - 10', '< 5', '> 10'])
ax.bar_label(ax.containers[0]) 
plt.title('How long do students study at home [hrs]?');

# %% [markdown]
# From above bar chart shows the number of students spending time in weekly study hours

# %%
# Creating  color map to to visually highlight the aggregated results
df.groupby(['PracticeSport', 'WklyStudyHours', 'ParentEduc']).agg({'MathScore':'mean', 'ReadingScore':'mean', 'WritingScore':'mean'})\
.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_bb3ca_row0_col0, #T_bb3ca_row50_col0 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_bb3ca_row0_col1, #T_bb3ca_row22_col0, #T_bb3ca_row42_col1 {
#   background-color: #57a0ce;
#   color: #f1f1f1;
# }
# #T_bb3ca_row0_col2 {
#   background-color: #7cb7da;
#   color: #000000;
# }
# #T_bb3ca_row1_col0, #T_bb3ca_row30_col2 {
#   background-color: #2474b7;
#   color: #f1f1f1;
# }
# #T_bb3ca_row1_col1 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_bb3ca_row1_col2, #T_bb3ca_row37_col2 {
#   background-color: #2f7fbc;
#   color: #f1f1f1;
# }
# #T_bb3ca_row2_col0, #T_bb3ca_row14_col1 {
#   background-color: #add0e6;
#   color: #000000;
# }
# #T_bb3ca_row2_col1 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_bb3ca_row2_col2, #T_bb3ca_row14_col2 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_bb3ca_row3_col0, #T_bb3ca_row48_col0 {
#   background-color: #2c7cba;
#   color: #f1f1f1;
# }
# #T_bb3ca_row3_col1, #T_bb3ca_row21_col1 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_bb3ca_row3_col2 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_bb3ca_row4_col0 {
#   background-color: #8dc1dd;
#   color: #000000;
# }
# #T_bb3ca_row4_col1 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_bb3ca_row4_col2 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_bb3ca_row5_col0 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_bb3ca_row5_col1 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_bb3ca_row5_col2 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_bb3ca_row6_col0 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_bb3ca_row6_col1, #T_bb3ca_row32_col2 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_bb3ca_row6_col2, #T_bb3ca_row28_col2 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_bb3ca_row7_col0 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_bb3ca_row7_col1, #T_bb3ca_row36_col1 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_bb3ca_row7_col2 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_bb3ca_row8_col0 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_bb3ca_row8_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_bb3ca_row8_col2 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_bb3ca_row9_col0, #T_bb3ca_row43_col2 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_bb3ca_row9_col1, #T_bb3ca_row49_col1 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_bb3ca_row9_col2, #T_bb3ca_row45_col1 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_bb3ca_row10_col0, #T_bb3ca_row23_col1 {
#   background-color: #c4daee;
#   color: #000000;
# }
# #T_bb3ca_row10_col1, #T_bb3ca_row20_col2 {
#   background-color: #a6cee4;
#   color: #000000;
# }
# #T_bb3ca_row10_col2 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_bb3ca_row11_col0, #T_bb3ca_row11_col1, #T_bb3ca_row11_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_bb3ca_row12_col0 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_bb3ca_row12_col1 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_bb3ca_row12_col2, #T_bb3ca_row24_col0 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_bb3ca_row13_col0 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_bb3ca_row13_col1 {
#   background-color: #58a1cf;
#   color: #f1f1f1;
# }
# #T_bb3ca_row13_col2 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_bb3ca_row14_col0, #T_bb3ca_row23_col0 {
#   background-color: #a4cce3;
#   color: #000000;
# }
# #T_bb3ca_row15_col0, #T_bb3ca_row45_col0 {
#   background-color: #3e8ec4;
#   color: #f1f1f1;
# }
# #T_bb3ca_row15_col1 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_bb3ca_row15_col2 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_bb3ca_row16_col0, #T_bb3ca_row20_col1 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_bb3ca_row16_col1, #T_bb3ca_row28_col1 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_bb3ca_row16_col2, #T_bb3ca_row26_col0, #T_bb3ca_row38_col0 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_bb3ca_row17_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_bb3ca_row17_col1 {
#   background-color: #d8e7f5;
#   color: #000000;
# }
# #T_bb3ca_row17_col2 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_bb3ca_row18_col0 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_bb3ca_row18_col1 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_bb3ca_row18_col2, #T_bb3ca_row25_col1 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_bb3ca_row19_col0 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_bb3ca_row19_col1 {
#   background-color: #125da6;
#   color: #f1f1f1;
# }
# #T_bb3ca_row19_col2 {
#   background-color: #1865ac;
#   color: #f1f1f1;
# }
# #T_bb3ca_row20_col0 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_bb3ca_row21_col0, #T_bb3ca_row39_col0 {
#   background-color: #0d57a1;
#   color: #f1f1f1;
# }
# #T_bb3ca_row21_col2 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_bb3ca_row22_col1 {
#   background-color: #69add5;
#   color: #f1f1f1;
# }
# #T_bb3ca_row22_col2, #T_bb3ca_row24_col2, #T_bb3ca_row32_col1 {
#   background-color: #63a8d3;
#   color: #f1f1f1;
# }
# #T_bb3ca_row23_col2 {
#   background-color: #c6dbef;
#   color: #000000;
# }
# #T_bb3ca_row24_col1, #T_bb3ca_row52_col1 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_bb3ca_row25_col0 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_bb3ca_row25_col2 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_bb3ca_row26_col1, #T_bb3ca_row38_col1 {
#   background-color: #bcd7eb;
#   color: #000000;
# }
# #T_bb3ca_row26_col2 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_bb3ca_row27_col0 {
#   background-color: #2777b8;
#   color: #f1f1f1;
# }
# #T_bb3ca_row27_col1 {
#   background-color: #0a549e;
#   color: #f1f1f1;
# }
# #T_bb3ca_row27_col2 {
#   background-color: #0c56a0;
#   color: #f1f1f1;
# }
# #T_bb3ca_row28_col0, #T_bb3ca_row46_col0 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_bb3ca_row29_col0, #T_bb3ca_row53_col2 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_bb3ca_row29_col1 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_bb3ca_row29_col2, #T_bb3ca_row47_col0 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_bb3ca_row30_col0 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_bb3ca_row30_col1 {
#   background-color: #206fb4;
#   color: #f1f1f1;
# }
# #T_bb3ca_row31_col0 {
#   background-color: #083a7a;
#   color: #f1f1f1;
# }
# #T_bb3ca_row31_col1, #T_bb3ca_row31_col2, #T_bb3ca_row33_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_bb3ca_row32_col0 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_bb3ca_row33_col1, #T_bb3ca_row39_col2 {
#   background-color: #08468b;
#   color: #f1f1f1;
# }
# #T_bb3ca_row33_col2 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_bb3ca_row34_col0, #T_bb3ca_row48_col1 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_bb3ca_row34_col1 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_bb3ca_row34_col2 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_bb3ca_row35_col0 {
#   background-color: #9fcae1;
#   color: #000000;
# }
# #T_bb3ca_row35_col1, #T_bb3ca_row41_col1 {
#   background-color: #cbdef1;
#   color: #000000;
# }
# #T_bb3ca_row35_col2, #T_bb3ca_row53_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_bb3ca_row36_col0 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_bb3ca_row36_col2 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# #T_bb3ca_row37_col0 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_bb3ca_row37_col1 {
#   background-color: #2979b9;
#   color: #f1f1f1;
# }
# #T_bb3ca_row38_col2 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_bb3ca_row39_col1 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_bb3ca_row40_col0, #T_bb3ca_row42_col0, #T_bb3ca_row42_col2, #T_bb3ca_row52_col2 {
#   background-color: #6caed6;
#   color: #f1f1f1;
# }
# #T_bb3ca_row40_col1 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_bb3ca_row40_col2 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_bb3ca_row41_col0 {
#   background-color: #bad6eb;
#   color: #000000;
# }
# #T_bb3ca_row41_col2 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_bb3ca_row43_col0 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_bb3ca_row43_col1 {
#   background-color: #3282be;

# %% [markdown]
# The colormap shows the student scores in various scenario's like in participating sports, spending more time to study, parent educational background vice versa

# %% [markdown]
# # Conclusion

# %% [markdown]
# The Student_Score dataset provides values insights of Student result based on their performance. Through careful analysis of the given data. Several keys are found
# - Parents educational background has impact on student scores.
# - Weekly study hours has impact on student scores.
# - Females scores percentage is more than the males scores.
# - By comparing ethinic groups group E has highest percentage and group A has lowest percentage.
